# %% [markdown]
# ### Outline on data

# %%
# !pip install missingno

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.shape
# Out:
# (768, 9)

# %%
print(df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
column = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]
df[column] = df[column].replace(0, np.nan)
plot = msno.bar(df)
plt.show()

# %% [markdown]
# Analysing the insulin, glucose and outcome column

# %%
positive = df[df['Outcome'] == 1]
print(positive.isna().sum())
Skinthickness_positive = positive[positive.SkinThickness.isna()]
Skinthickness_positive.sample(25)
# Out:
# Pregnancies                   0
# Glucose                       2
# BloodPressure                16
# SkinThickness                88
# Insulin                     138
# BMI                           2
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 443            8    108.0           70.0            NaN      NaN  30.5
# 283            7    161.0           86.0            NaN      NaN  30.4
# 676            9    156.0           86.0            NaN      NaN  24.8
# 15             7    100.0            NaN            NaN      NaN  30.0
# 739            1    102.0           74.0            NaN      NaN  39.5
# 675            6    195.0           70.0            NaN      NaN  30.9
# 84             5    137.0          108.0            NaN      NaN  48.8
# 17             7    107.0           74.0            NaN      NaN  29.6
# ...

# %%
negative = df[df['Outcome'] == 0]
print(negative.isna().sum())
Skinthickness_negative = negative[negative.SkinThickness.isna()]
Skinthickness_negative.sample(25)
# Out:
# Pregnancies                   0
# Glucose                       3
# BloodPressure                19
# SkinThickness               139
# Insulin                     236
# BMI                           9
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 294            0    161.0           50.0            NaN      NaN  21.9
# 728            2    175.0           88.0            NaN      NaN  22.9
# 653            2    120.0           54.0            NaN      NaN  26.8
# 474            4    114.0           64.0            NaN      NaN  28.9
# 184            4    141.0           74.0            NaN      NaN  27.6
# 336            0    117.0            NaN            NaN      NaN  33.8
# 5              5    116.0           74.0            NaN      NaN  25.6
# 168            4    110.0           66.0            NaN      NaN  31.9
# ...

# %%
Skinthickness_positive = positive[positive.Insulin.isna()]
Skinthickness_positive.sample(25)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 349            5      NaN           80.0           32.0      NaN  41.0
# 739            1    102.0           74.0            NaN      NaN  39.5
# 129            0    105.0           84.0            NaN      NaN  27.9
# 702            1    168.0           88.0           29.0      NaN  35.0
# 451            2    134.0           70.0            NaN      NaN  28.9
# 124            0    113.0           76.0            NaN      NaN  33.3
# 242            3    139.0           54.0            NaN      NaN  25.6
# 598            1    173.0           74.0            NaN      NaN  36.8
# 510           12     84.0           72.0           31.0      NaN  29.7
# 66             0    109.0           88.0           30.0      NaN  32.5
# 0              6    148.0           72.0           35.0      NaN  33.6
# 100            1    163.0           72.0            NaN      NaN  39.0
# ...

# %%
Skinthickness_negative = negative[negative.Insulin.isna()]
Skinthickness_negative.sample(25)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 728            2    175.0           88.0            NaN      NaN  22.9
# 79             2    112.0           66.0           22.0      NaN  25.0
# 180            6     87.0           80.0            NaN      NaN  23.2
# 491            2     89.0           90.0           30.0      NaN  33.5
# 602            1    124.0           74.0           36.0      NaN  27.8
# 58             0    146.0           82.0            NaN      NaN  40.5
# 55             1     73.0           50.0           10.0      NaN  23.0
# 178            5    143.0           78.0            NaN      NaN  45.0
# 344            8     95.0           72.0            NaN      NaN  36.8
# 643            4     90.0            NaN            NaN      NaN  28.0
# 196            1    105.0           58.0            NaN      NaN  24.3
# 512            9     91.0           68.0            NaN      NaN  24.2
# ...

# %%
df=df.drop('Insulin', axis=1)

# %%
df.isna().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
rows=6
col=2    
for i in df:
    plt.figure(figsize=(22,50))
    fig=1
    plt.subplot(rows,col,fig)
    sns.distplot(df[i])
    fig=fig+1
    plt.subplot(rows,col,fig)
    sns.boxplot(df[i])
    fig=fig+1
    plt.show()

# %% [markdown]
# We now handle the outliers using IQR Based Filtering.

# %%
row=6
col=2
fig=1
for i in df:
    print(i)
    
    #finding IQR
    percentile25 = df[i].quantile(0.25)
    percentile75 = df[i].quantile(0.75)

    #Finding the upper and lower limits
    Q3 = np.quantile(df[i], 0.75)
    Q1 = np.quantile(df[i], 0.25)
    iqr= Q3 - Q1
    upper_limit = percentile75 + 1.5 * iqr
    lower_limit = percentile25 - 1.5 * iqr 
    
    new_df = df[[df[i] < upper_limit] and [df[i] > lower_limit]]
    new_df
    
    plt.figure(figsize=(12,5))
    plt.subplot(rows,col,fig)
    sns.boxplot(df[i])
    fig=fig+1
    plt.show()
    
    plt.figure(figsize=(12,5))
    plt.subplot(rows,col,fig)
    sns.boxplot(new_df[i])
    fig=fig+1
    plt.show()
# Out:
# Pregnancies
# Glucose
# BloodPressure
# BMI
# DiabetesPedigreeFunction
# Age
# Outcome

# %%
#trimming outliers
new_df = df[df['Pregnancies'] < upper_limit]
new_df.shape

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['Pregnancies'])
plt.subplot(2,2,2)
sns.boxplot(df['Pregnancies'])
plt.subplot(2,2,3)
sns.distplot(new_df['Pregnancies'])
plt.subplot(2,2,4)
sns.boxplot(new_df['Pregnancies'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/63/p04rpb2x3h3ffh1xvy1qc2sc0000gn/T/ipykernel_87161/2422050087.py in <module>
#      11 sns.distplot(new_df['Pregnancies'])
#      12 plt.subplot(2,2,4)
# ---> 13 sns.boxplot(new_df['Pregnancies'],kwargs=0.2)
#      14 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2249     kwargs.update(dict(whis=whis))
#    2250
# -> 2251     plotter.plot(ax, kwargs)
# ...

# %%
def outlier_cap_trim(a):
    pass
